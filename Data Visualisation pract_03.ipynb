# %% [markdown]
# # Seaborn

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os

# %%
#here we had to fix the difrectory
#os.chdir('')
#axis is rowwise
#inplace is actually changed val
cars_data=pd.read_csv('C://Users//Akshay Waje//Downloads//Toyota.csv - Toyota.csv (1).csv', index_col=0,na_values=['??',"????"])
cars_data.size
# Out:
# 14360

# %%
cars_data.dropna(axis=0,inplace=True)
cars_data.size
# Out:
# 10960

# %%
cars_data=pd.read_csv('C://Users//Akshay Waje//Downloads//Toyota.csv - Toyota.csv (1).csv',index_col=0)
cars_data.head()
# Out:
#    Price   Age     KM FuelType  HP  MetColor  Automatic    CC  Doors  Weight
# 0  13500  23.0  46986   Diesel  90       1.0          0  2000  three    1165
# 1  13750  23.0  72937   Diesel  90       1.0          0  2000      3    1165
# 2  13950  24.0  41711   Diesel  90       NaN          0  2000      3    1165
# 3  14950  26.0  48000   Diesel  90       0.0          0  2000      3    1165
# 4  13750  30.0  38500   Diesel  90       0.0          0  2000      3    1170

# %%
# to get grid line background

sns.set(style='darkgrid')
sns.regplot(x=cars_data['Age'],y=cars_data['Price'])

# %%
#to remove line
sns.regplot(x=cars_data['Age'],y=cars_data['Price'],fit_reg=False)

# %%
# to change the marker 
sns.regplot(x=cars_data['Age'],y=cars_data['Price'],marker="*",fit_reg=False)

# %%
#add 3rd dimension by hue 
#PALETTE IS A SET OF COLORS SET1, SET2 ETC 
sns.lmplot(x='Age', y='Price', data=cars_data, fit_reg=False, hue='FuelType',legend=True,palette='Set1')

# %%
#histogram using dislot

sns.distplot(cars_data['Age'])

# %%
sns.distplot(cars_data['Age'],kde=False)
#kde is kernal density

# %%
# to check particular bins means 1st 5 bins only
sns.distplot(cars_data['Age'],kde=False, bins=5)

# %%
#barplot using sns
sns.countplot(x='FuelType',data=cars_data)

# %%
#
sns.countplot(x='FuelType',data=cars_data,hue='Automatic')

# %%
#above plot detail explaination or to crosscheck data
pd.crosstab(index=cars_data['Automatic'], columns=cars_data['FuelType'],dropna=True)
# Out:
# FuelType   CNG  Diesel  Petrol
# Automatic
# 0           15     144    1104
# 1            0       0      73

# %% [markdown]
# # Box and whiskers plot

# %%
#here extreme two lines given upper and lower lines, in the box 3 lines are 25%, 50% & 75% ,
# and dots are outliers.
sns.boxplot(x=cars_data['FuelType'], y=cars_data['Price'])

# %%
sns.boxplot(x='FuelType' , y=cars_data['Price'],hue='Automatic', data=cars_data)

# %%
f,(ax_box,ax_hist)=plt.subplots(2,gridspec_kw={"height_ratios": (.15, .85)})

# %%
f,(ax_box,ax_hist)=plt.subplots(2,gridspec_kw={"height_ratios": (.15, .85)})
sns.boxplot(cars_data['Price'],ax=ax_box)
sns.distplot(cars_data['Price'],ax=ax_hist,kde=False)

# %%
sns.pairplot(cars_data, kind="scatter", hue="FuelType", diag_kws={'bw':0.1})
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:288: UserWarning: Data must have variance to compute a kernel density estimate.
#   warnings.warn(msg, UserWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:288: UserWarning: Data must have variance to compute a kernel density estimate.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# # Heatmap

# %%
# it shows correlation between the every value betn the table
#used to see whether tv channel TRP range or views of it

# %%
my_data=np.random.randint(1,100,size=(10,10))
print("The data to be plotted: \n")
print(my_data)
# Out:
# The data to be plotted:
#
# [[25 32 71 92 99 73 37 30 32 86]
#  [25 65 43 10  5 23 40 33 33 15]
#  [94 76 44 42 29 28 29  3 45 79]
#  [62 77 80 41 61 54 74 29 24 62]
#  [72 14 30 57 30 27 82 20  6 69]
#  [46 64 62 47 78 63  1 39 99 10]
#  [45 33 44  2 98  2 43 89 91 36]
#  [68 16 57 79 41 84  5 89 19  2]
#  [34 22 85 65  4 53 90 23 96  6]
#  [52 91 97 55 84  6 25 91 40 71]]

# %%
heatmap= sns.heatmap(data=my_data)
plt.show()

# %%
hm=sns.heatmap(data=my_data,
              vmin='30',
              vmax='70')
plt.show()

# %%
#setting the parameter value
# to change the color set i.e cmap ="tab20", "tab10", "tab30"
#annot is parameter value prints in color
cmap="Blues" 
center=0

#setting the parameter values
annot = True

#plotting the heatmap
hm=sns.heatmap(data=my_data,cmap=cmap, annot=annot)

plt.show()
