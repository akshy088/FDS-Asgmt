# %% [markdown]
# # Scatter Plot

# %%
# to findings the relation

# %%
import matplotlib.pyplot as plt
fig, zx = plt.subplots()

x=[1,2,5,4,7,8,9,6,8,7,4,5,6,6,5,7,8,5,4,5,4,5,4]
y=[2,7,8,9,5,4,5,8,9,6,8,7,4,5,8,9,6,5,4,7,8,5,6]
zx.scatter(x, y)

# %%
import pandas as pd
iris= pd.read_csv('C://Users//Akshay Waje//Downloads//Iris.csv - Iris.csv.csv', index_col = 0)
print(iris.head())
# Out:
#     SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# Id
# 1             5.1           3.5            1.4           0.2  Iris-setosa
# 2             4.9           3.0            1.4           0.2  Iris-setosa
# 3             4.7           3.2            1.3           0.2  Iris-setosa
# 4             4.6           3.1            1.5           0.2  Iris-setosa
# 5             5.0           3.6            1.4           0.2  Iris-setosa

# %%
import matplotlib.pyplot as plt
#creat a fig
fig, ax = plt.subplots()
#scatter the sepal_length against sepal_width
ax.scatter(iris['SepalLengthCm'], iris['SepalWidthCm'])
#set a title and labels
ax.set_title('Iris Dataset')
ax.set_xlabel('sepal_LengthCm')
ax.set_ylabel('sepal_WidthCm')
# Out:
# Text(0, 0.5, 'sepal_WidthCm')

# %%
#to plot line connected scatter points
import pandas as pd 
import numpy as np
from matplotlib import pyplot as plt
x=range(1,6)
y=np.random.randint(1,20,5)
plt.plot(x,y)
#to plot the numbers on axis 
plt.xticks(x)
plt.yticks(y)
# Out:
# ([<matplotlib.axis.YTick at 0x1bb87f78f08>,
# ...
#  <a list of 5 Text yticklabel objects>)

# %%
import pandas as pd
df = pd.DataFrame({
    'name':['john','akshay','ram','ganesh','jacob','hatch'],
    'gender':['M','M','F','M','F','M'],
    'age':[20,12,45,12,52,41],
    'state':['cali','up','mp','rj','lp','ki'],
    'num_children':[2,1,0,2,2,3],
    'num_pets':[5,1,2,3,6,5]
})

ax = plt.gca()

df.plot(kind='line', x='name',y='num_children', ax=ax)
df.plot(kind='line', x='state',y='num_pets', ax=ax)

# %%
#get columns to plot
columns = iris.columns.drop(['Species'])
#create x data
x_data = range(0, iris.shape[0])
#create fig and axis
fig, ax = plt.subplots()
#plot each column
for col in columns:
    ax.plot(x_data, iris[col], label=col)
#set title and legend
ax.set_title('Iris Dataset')
ax.legend()
#legend is for show of all colors line

# %% [raw]
# #Histogram (frequency of particular var)

# %%
#create fig and axis
fig, ax = plt.subplots()
#plot hstogram 
ax.hist(iris['SepalLengthCm'])

#set titles and labels
ax.set_title('iris')
ax.set_xlabel('sepal_len')
ax.set_ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %%
# Bar chartax

# %%
#create a fig and axis
fig, ax  = plt.subplots()
#count the occurence of each class
data = iris['SepalLengthCm'].value_counts()
#get x& y
points = data.index
frequency = data.values
# cretae bar chart
ax.bar(points, frequency)


#label
ax.set_title('iris')
ax.set_xlabel('iris_x')
ax.set_ylabel('frequency')
# Out:
# Text(0, 0.5, 'frequency')

# %%
iris['SepalLengthCm'].value_counts().sort_index().plot.bar()

# %%
iris.groupby('SepalWidthCm').SepalWidthCm.mean().sort_values(ascending=False)[:5].plot.bar()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-74-109f2b7734ba> in <module>
# ----> 1 iris.groupby('SepalWidthCm').SepalWidthCm.mean().sort_values(ascending=False)[:5].plot.bar()
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\plotting\_core.py in bar(self, x, y, **kwargs)
#    1001             >>> ax = df.plot.bar(x='lifespan', rot=0)
#    1002         """
# -> 1003         return self(kind="bar", x=x, y=y, **kwargs)
#    1004
#    1005     def barh(self, x=None, y=None, **kwargs):
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\plotting\_core.py in __call__(self, *args, **kwargs)
#     845                     data.columns = label_name
#     846
# --> 847         return plot_backend.plot(data, kind=kind, **kwargs)
#     848
#     849     __call__.__doc__ = __doc__
#
# ...

# %%
import pandas as pd
wine_reviews = pd.read_csv('C://Users//Akshay Waje//Downloads//winemag-data-130k-v2.csv', index_col=0)
print(wine_reviews.head())
# Out:
#     country                                        description  \
# 0     Italy  Aromas include tropical fruit, broom, brimston...
# 1  Portugal  This is ripe and fruity, a wine that is smooth...
# 2        US  Tart and snappy, the flavors of lime flesh and...
# 3        US  Pineapple rind, lemon pith and orange blossom ...
# 4        US  Much like the regular bottling from 2012, this...
#
#                           designation  points  price           province  \
# 0                        Vulkà Bianco      87    NaN  Sicily & Sardinia
# 1                            Avidagos      87   15.0              Douro
# 2                                 NaN      87   14.0             Oregon
# 3                Reserve Late Harvest      87   13.0           Michigan
# 4  Vintner's Reserve Wild Child Block      87   65.0             Oregon
#
#               region_1           region_2         taster_name  \
# 0                 Etna                NaN       Kerin O’Keefe
# ...

# %%
#for wine table
wine_reviews['points'].value_counts().sort_index().plot.bar()

# %%
wine_reviews.groupby('country').price.mean().sort_values(ascending=False)[:5].plot.bar()

# %%
# alpha is tranparancy of colored graph
import numpy as np
import matplotlib.pyplot as plt
objects = ('Python','R','java','Perl','Scala','Linux')
y_pos = np.arange(len(objects))
performance = [10,8,7,4,6,6]

plt.bar(y_pos, performance, width=0.5, align= 'center', alpha=0.7, color=['r','r','g','g','b','b'],edgecolor='red')
plt.xticks(y_pos, objects)
#title
plt.ylabel('usage')
plt.xlabel('Proramming lang')
plt.title('Programming lang usage')
# Out:
# Text(0.5, 1.0, 'Programming lang usage')

# %% [markdown]
# # FDS 21/09

# %%
import pandas as pd

wine_reviews = pd.read_csv('C://Users//Akshay Waje//Downloads//winemag-data-130k-v2.csv')
wine_reviews.head()
# Out:
#    Unnamed: 0   country                                        description  \
# 0           0     Italy  Aromas include tropical fruit, broom, brimston...
# 1           1  Portugal  This is ripe and fruity, a wine that is smooth...
# 2           2        US  Tart and snappy, the flavors of lime flesh and...
# 3           3        US  Pineapple rind, lemon pith and orange blossom ...
# 4           4        US  Much like the regular bottling from 2012, this...
#
#                           designation  points  price           province  \
# 0                        Vulkà Bianco      87    NaN  Sicily & Sardinia
# 1                            Avidagos      87   15.0              Douro
# 2                                 NaN      87   14.0             Oregon
# 3                Reserve Late Harvest      87   13.0           Michigan
# 4  Vintner's Reserve Wild Child Block      87   65.0             Oregon
#
#               region_1           region_2         taster_name  \
# ...

# %%
wine_reviews['points'].value_counts().sort_index().plot.barh()

# %%
import matplotlib.pyplot as plt
#declaring the fig or the pplot (y,x) or (width,height)
plt.figure(figsize=[14,10])

#passing the parametes to the bar function this is the 
#for creating the horizontal make sure that you append  'h' 
plt.barh(['USA', 'Brazil', 'Russia ','Spain', 'UK'],[2026493,710887, 476658,288797,287399],label = "Daner zone" , color='r')
plt.barh(['India','Italy','Peru','Germany','Iran'],[265928,235278,199696,186205,173832], label='Not safe zone', color='b')
plt.legend()

plt.xlabel('Total cases')
plt.ylabel('Countries')

plt.title('top ten countries most afected by /n corona virus')
plt.savefig('2barPlot.png')
plt.show()

# %%
import pandas as pd
df = pd.DataFrame({
    'name':['john','akshay','ram','ganesh','jacob','hatch'],
    'gender':['M','M','F','M','F','M'],
    'age':[23,22,25,26,21,65],
    'state':['cali','up','mp','rj','MK','lp'],
    'num_children':[2,1,0,2,2,3],
    'num_pets':[5,1,0,5,2,2]
})


#from pandas to plot multiple plots on same fig
df.groupby(['state', 'gender']).size().unstack().plot(kind='bar' , stacked=True)

# %%
df.groupby(['state', 'num_pets']).size().unstack().plot(kind='bar' , stacked=True)

# %%
import pandas as pd 
from matplotlib import pyplot as plt


Data={'Country':['USA','Canada','Germany','UK','France'],
     'Gdp_Per_Capita':[4500,42000,52000,49000,47000],
     'Income_Per_Capita':[4000,5000,7000,55000,60000]
     }


df = pd.DataFrame(Data)

df.plot(x='Country',y=['Gdp_Per_Capita', 'Income_Per_Capita', Kind='bar')
# Out:
#   File "<ipython-input-24-fa9b9e746149>", line 13
#     df.plot(x='Country',y=['Gdp_Per_Capita', 'Income_Per_Capita', Kind='bar')
#                                                                       ^
# SyntaxError: invalid syntax

# %%
import numpy as np
import matplotlib.pyplot as plt

plt.figure(figsize=[15,10])

totalDeath=[113055,37312,5971,7473,33964]
totalRecovery=[773480,325602,230688,129095,166584]
activeCases=[1139958,347973,239999,129360,34730]
country=['USA','Brazil','Russia','India','Italy']

x=np.arange(len(totalDeath))

plt.bar(X, totalDeath, coolr='black', width=0.25)
plt.bat(X + 0.25, totalRecovery, color='g', width=0.25)
plt.bar(X + 0.5, astiveCases, color='b', width=0.25)

plt.legend(['total deaths', 'total recovery', 'active cases'])

plt.xticks([i + 0.25 for i in range(5)],country)
plt.title('barr')

plt.xlabel('countries')
plt.ylabel('cases')
plt.savefig('2barplot')

plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-80-c291a5d86e9b> in <module>
#      11 x=np.arange(len(totalDeath))
#      12
# ---> 13 plt.bar(X, totalDeath, coolr='black', width=0.25)
#      14 plt.bat(X + 0.25, totalRecovery, color='g', width=0.25)
#      15 plt.bar(X + 0.5, astiveCases, color='b', width=0.25)
#
# NameError: name 'X' is not defined

# %% [markdown]
# # piechart

# %%
#KDE = Kernal Density Estimates

# %%
from pandas import DataFrame
import matplotlib.pyplot as plt

Data={'Task':[300,500,700],
     'Task Type':['Task Pending','Task ongoing', 'Task completed']}

df = DataFrame(Data)
df.set_index('Task Type', inplace=True)


df.plot.pie(y='Task', figsize=(5,5), autopct='%1.1f%%', startangle=90)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

labels = ['civi','electrical', 'mechanical', 'chemical']
sizes=[15,30,45,10]
 
explode = (0.1,0.1,0.1,0.4)

fig,ax=plt.subplots()
ax.pie(sizes,
      explode=explode,
      labels=labels,
      autopct='%1.1f%%',
      shadow=True,
      startangle=90)

ax.axis('equal')
ax.set_title('engineering diciplines')
# Out:
# Text(0.5, 1.0, 'engineering diciplines')

# %% [markdown]
# # subplots

# %%
import numpy as np
plt.figure(figsize=(20,10))
plt.subplot(2,2,1)
plt.bar(range(1,6),np.random.randint(1,20,5))
plt.title('2,1,1')
plt.subplot(2,2,2)
plt.bar(range(1,6), np.random.randint(1,20,5))
plt.title('2,2,2')
plt.subplot(2,2,3)
#s is the size of the dot
plt.scatter(range(1,6), np.random.randint(1,20,5), s=100, color='r')
plt.title('2,2,3')
plt.subplot(2,2,4)
plt.plot(range(1,6), np.random.randint(1,20,5), marker='o', color='g', linestyle='--')
plt.title('2,2,4')
# Out:
# Text(0.5, 1.0, '2,2,4')

# %%
plt.bar(range(1,6),np.random.randint(1,20,5))
plt.scatter(range(1,6), np.random.randint(1,20,5), s=100, color='r')
plt.plot(range(1,6), np.random.randint(1,20,5), marker='o', color='g', linestyle='--')

# %% [markdown]
# # seaborn
